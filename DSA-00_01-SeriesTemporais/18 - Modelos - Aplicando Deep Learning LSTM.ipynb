# %% [markdown]
# <strong><b><font size="5">Aplicando Inteligência Artificial Para Prever a Média Mensal de Vendas</font></b></strong>

# %% [markdown]
# O que acha de trazer Inteligência Artificial para nossa conversa?
#
# De todos os modelos que criamos até aqui no curso, nenhum deles pode ser considerado Inteligência Artificial, mas a partir de agora usaremos Deep Learning, atualmente a principalmente técnica de IA e o estado de arte para a solução de diversos problemas, incluindo previsões de séries temporais.
#
# **Deep Learning - Modelo LSTM**
#
# Os problemas de previsão de séries temporais são um tipo difícil de problema de modelagem preditiva. As séries temporais adicionam a complexidade de uma dependência de sequência entre as variáveis de entrada.
#
# Um tipo poderoso de rede neural projetada para lidar com a dependência de sequência é chamado de Rede Neural Recorrente. A rede Long Short-Term Memory ou LSTM é um tipo de rede neural recorrente usada em aprendizado profundo que apresenta bons resultados, quando devidamente treinada.
#
# Esta e as próximas aulas consideram que você já tem alguma noção sobre o que é Deep Learning e a definição de Deep Learning.
#
# Esse conhecimento pode ser obtido no material gratuito fornecido pela DSA, o <a href="http://www.deeplearningbook.com.br/">Deep Learning Book</a>. Lá você encontra alguns capítulos inteiros dedicados às LSTMs. Recomendamos a leitura antes de prosseguir nesta aula.
#
# **No Google Colab, altere seu Runtime para executar o treinamento usando GPU**.
#
# Vamos ao trabalho.

# %% [markdown]
# ### Carregando os Pacotes Usados Neste Jupyter Notebook

# %%
# As novas versões do Pandas e Matplotlib trazem diversas mensagens de aviso ao desenvolvedor. Vamos desativar isso.
import sys
import warnings
import matplotlib.cbook
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=matplotlib.cbook.mplDeprecation)

# Imports para manipulação de dados
import numpy as np
import pandas as pd
import itertools
from pandas import Series
from pandas.tseries.offsets import DateOffset

# Imports para visualização de dados
import matplotlib.pyplot as plt
import matplotlib as m
import seaborn as sns

# Imports para modelagem preditiva
import sklearn
import keras
from sklearn.preprocessing import MinMaxScaler
from keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.layers import LSTM
from keras.layers import Dropout
import statsmodels
import statsmodels.api as sm
import statsmodels.tsa.api as smt
import statsmodels.stats as sms
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller

# Imports para formatação dos gráficos
m.rcParams['axes.labelsize'] = 14
m.rcParams['xtick.labelsize'] = 12
m.rcParams['ytick.labelsize'] = 12
m.rcParams['text.color'] = 'k'
from matplotlib.pylab import rcParams 
rcParams['figure.figsize'] = 15,7
matplotlib.style.use('ggplot')
# %matplotlib inline

# %% [markdown]
# ## Definição do Problema de Negócio
#
# A HappyMoonVC é uma Venture Capital (VC).
#
# Além do investimento no GoInRail (descrito nas aulas anteriores), a HappyMoonVC está analisando um outro negócio. Uma rede de varejo que poderá fornecer produtos para os clientes do GoInRail (drone elétrico para transporte de passageiros).
#
# Um monitor touch-screen dentro do GoInRail permitiria que o cliente fizesse a compra de produtos enquanto faz a viagem, com a opção de pegar o produto na estação que for descer ou então receber direto na residência (se acha que isso é futurista demais, saiba que já existe no metrô do Japão).
#
# Para decidir se o investimento vale a pena, a HappyMoonVC precisa prever o volume de vendas.
#
# Esse é nosso trabalho.

# %% [markdown]
# ## Conjunto de Dados

# %% [markdown]
# Usaremos conjuntos de dados que está disponível publicamente no site do Tableau e que representa as vendas históricas da empresa na qual a HappyMoonVC pretende investir. Aqui o link do dataset (que está sendo fornecido para você):
#
# https://community.tableau.com/docs/DOC-1236
#
# De todos os dados disponíveis, nosso interesse é na categoria de produtos de tecnologia.

# %%
# Carrega os dados
dados = pd.read_csv('data/vendasHistoricas.csv')

# %%
# Shape
dados.shape
# Out:
# (9994, 21)

# %%
# Colunas
dados.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# ### Análise Exploratória

# %%
# Visualizando os dados
dados.head(3)
# Out:
#    Row ID        Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156  2016-11-08  2016-11-11  Second Class    CG-12520
# 1       2  CA-2016-152156  2016-11-08  2016-11-11  Second Class    CG-12520
# 2       3  CA-2016-138688  2016-06-12  2016-06-16  Second Class    DV-13045
#
#      Customer Name    Segment        Country         City  ... Postal Code  \
# 0      Claire Gute   Consumer  United States    Henderson  ...       42420
# 1      Claire Gute   Consumer  United States    Henderson  ...       42420
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  ...       90036
#
#    Region       Product ID         Category Sub-Category  \
# 0   South  FUR-BO-10001798        Furniture    Bookcases
# 1   South  FUR-CH-10000454        Furniture       Chairs
# 2    West  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.62         2
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
# 2       0.0    6.8714
#
# [3 rows x 21 columns]

# %%
# Resumo estatístico
dados.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
# Checando valores missing - não temos valores missing no dataset
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: float64(3), int64(3), object(15)
# memory usage: 1.6+ MB

# %%
# Ajustando o nome das colunas para que todas fiquem com letras minúsculas
dados.columns = map(str.lower, dados.columns)

# %%
# Vamos substituir os espaços e traços nos nomes das colunas por '_'
dados.columns = dados.columns.str.replace(" ", "_")
dados.columns = dados.columns.str.replace("-", "_")

# %%
# Conferindo
dados.columns
# Out:
# Index(['row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode',
#        'customer_id', 'customer_name', 'segment', 'country', 'city', 'state',
#        'postal_code', 'region', 'product_id', 'category', 'sub_category',
#        'product_name', 'sales', 'quantity', 'discount', 'profit'],
#       dtype='object')

# %% [markdown]
# Vamos separar os dados por categoria (Móveis, Tecnologia, Material de escritório).

# %%
# Separando os dados por categoria
df_tecnologia = dados.loc[dados['category'] == 'Technology']
df_moveis = dados.loc[dados['category'] == 'Furniture']
df_office = dados.loc[dados['category'] == 'Office Supplies']

# %% [markdown]
# Agora vamos preparar as séries temporais.

# %%
# Agregando as vendas pela data do pedido
ts_tecnologia = df_tecnologia.groupby('order_date')['sales'].sum().reset_index()
ts_moveis = df_moveis.groupby('order_date')['sales'].sum().reset_index()
ts_office = df_office.groupby('order_date')['sales'].sum().reset_index()

# %%
# Como está ficando o nosso dataset de interesse?
ts_tecnologia
# Out:
#      order_date     sales
# 0    2014-01-06  1147.940
# 1    2014-01-09    31.200
# 2    2014-01-13   646.740
# 3    2014-01-15   149.950
# 4    2014-01-16   124.200
# ..          ...       ...
# 819  2017-12-25   401.208
# 820  2017-12-27   164.388
# 821  2017-12-28    14.850
# 822  2017-12-29   302.376
# 823  2017-12-30    90.930
#
# [824 rows x 2 columns]

# %% [markdown]
# Vamos mover a data para o índice e assim criar a série temporal.

# %%
# Colocando a data como índice
ts_tecnologia = ts_tecnologia.set_index('order_date')

# %%
# Visualizando a série
ts_tecnologia
# Out:
#                sales
# order_date
# 2014-01-06  1147.940
# 2014-01-09    31.200
# 2014-01-13   646.740
# 2014-01-15   149.950
# 2014-01-16   124.200
# ...              ...
# 2017-12-25   401.208
# 2017-12-27   164.388
# 2017-12-28    14.850
# 2017-12-29   302.376
# 2017-12-30    90.930
#
# [824 rows x 1 columns]

# %% [markdown]
# Agora podemos conferir a performance de vendas ao longo do tempo.

# %%
# Venda de Produtos de Tecnologia
vendas_tecnologia = ts_tecnologia[['sales']]
ax = vendas_tecnologia.plot(color = 'b', figsize = (18,6))
plt.xlabel("Data")
plt.ylabel('Vendas')
plt.title("Venda de Produtos de Tecnologia")
plt.show()

# %% [markdown]
# Vamos ajustar o indice do tipo Index para o tipo DateTimeIndex (o que caracteriza uma série temporal), pois faremos uma agregação pela média para analisar a venda média ao longo do tempo.

# %%
# Conferindo o tipo do índice
type(vendas_tecnologia.index)
# Out:
# pandas.core.indexes.base.Index

# %%
# Alterando o tipo do índice
vendas_tecnologia.index = pd.to_datetime(vendas_tecnologia.index)

# %%
# Conferindo o tipo do índice
type(vendas_tecnologia.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
# Reamostrando os dados para frequência mensal
# Usando o valor médio das vendas diárias - definimos o mês como índice
media_vendas_tecnologia = vendas_tecnologia['sales'].resample('MS').mean()

# %%
# Verificando o tipo resultante
type(media_vendas_tecnologia)
# Out:
# pandas.core.series.Series

# %%
# Checando os dados
media_vendas_tecnologia
# Out:
# order_date
# 2014-01-01     449.041429
# 2014-02-01     229.787143
# 2014-03-01    2031.948375
# 2014-04-01     613.028933
# 2014-05-01     564.698588
# 2014-06-01     766.905909
# 2014-07-01     533.608933
# 2014-08-01     708.435385
# 2014-09-01    2035.838133
# 2014-10-01     596.900900
# 2014-11-01    1208.056320
# 2014-12-01    1160.732889
# 2015-01-01     925.070800
# 2015-02-01     431.121250
# 2015-03-01     574.662333
# 2015-04-01     697.559500
# 2015-05-01     831.642857
# 2015-06-01     429.024400
# 2015-07-01     691.397733
# 2015-08-01    1108.902286
# 2015-09-01     950.856400
# 2015-10-01     594.716111
# 2015-11-01    1037.982652
# 2015-12-01    1619.637636
# 2016-01-01     374.671067
# 2016-02-01    1225.891400
# 2016-03-01    1135.150105
# 2016-04-01     875.911882
# 2016-05-01    1601.816167
# 2016-06-01    1023.259500
# 2016-07-01     829.312500
# 2016-08-01     483.620100
# 2016-09-01    1144.170300
# 2016-10-01    1970.835875
# 2016-11-01    1085.642360
# 2016-12-01     970.554870
# 2017-01-01    1195.218071
# 2017-02-01     430.501714
# 2017-03-01    1392.859250
# 2017-04-01     825.559133
# 2017-05-01     678.329400
# 2017-06-01     853.055000
# 2017-07-01    1054.996636
# 2017-08-01     978.842333
# 2017-09-01    1077.704120
# 2017-10-01    1493.439227
# 2017-11-01    1996.750920
# 2017-12-01     955.865652
# Freq: MS, Name: sales, dtype: float64

# %%
# Venda Média de Produtos de Tecnologia
media_vendas_tecnologia.plot(figsize = (18, 6), color = 'blue')
plt.xlabel("Data de Compra")
plt.ylabel('Vendas')
plt.title("Venda Média de Produtos de Tecnologia")
plt.show()

# %% [markdown]
# Agora, vamos decompor uma das séries para avaliar seus componentes.

# %%
# Decomposição da série temporal de venda média de produtos de tecnologia
decomposition = seasonal_decompose(media_vendas_tecnologia, period = 12)
rcParams['figure.figsize'] = 18, 12

# Componentes
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# Plot
plt.subplot(411)
plt.plot(media_vendas_tecnologia, label = 'Série Original')
plt.legend(loc = 'best')
plt.subplot(412)
plt.plot(trend, label = 'Tendência')
plt.legend(loc = 'best')
plt.subplot(413)
plt.plot(seasonal, label = 'Sazonalidade')
plt.legend(loc = 'best')
plt.subplot(414)
plt.plot(residual, label = 'Resíduos')
plt.legend(loc = 'best')
plt.tight_layout()

# %% [markdown]
# Vamos testar a estacionaridade.

# %%
# Função para testar a estacionaridade
def testa_estacionaridade(serie):
    
    # Calcula estatísticas móveis
    rolmean = serie.rolling(window = 12).mean()
    rolstd = serie.rolling(window = 12).std()

    # Plot das estatísticas móveis
    plt.figure(figsize = (20, 6))
    orig = plt.plot(serie, color = 'blue', label = 'Original')
    mean = plt.plot(rolmean, color = 'red', label = 'Média Móvel')
    std = plt.plot(rolstd, color = 'black', label = 'Desvio Padrão')
    plt.legend(loc = 'best')
    plt.title('Estatísticas Móveis - Média e Desvio Padrão')
    plt.show()
    
    # Teste Dickey-Fuller:
    # Print
    print('\nResultado do Teste Dickey-Fuller:\n')

    # Teste
    dfteste = adfuller(serie, autolag = 'AIC')

    # Formatando a saída
    dfsaida = pd.Series(dfteste[0:4], index = ['Estatística do Teste',
                                               'Valor-p',
                                               'Número de Lags Consideradas',
                                               'Número de Observações Usadas'])

    # Loop por cada item da saída do teste
    for key, value in dfteste[4].items():
        dfsaida['Valor Crítico (%s)'%key] = value

    # Print
    print (dfsaida)
    
    # Testa o valor-p
    print ('\nConclusão:')
    if dfsaida[1] > 0.05:
        print('\nO valor-p é maior que 0.05 e, portanto, não temos evidências para rejeitar a hipótese nula.')
        print('Essa série provavelmente não é estacionária.')
    else:
        print('\nO valor-p é menor que 0.05 e, portanto, temos evidências para rejeitar a hipótese nula.')
        print('Essa série provavelmente é estacionária.')

# %%
# Verifica se a série é estacionária
testa_estacionaridade(media_vendas_tecnologia)
# Out:
# Resultado do Teste Dickey-Fuller:
#
# Estatística do Teste           -7.187969e+00
# Valor-p                         2.547334e-10
# Número de Lags Consideradas     0.000000e+00
# Número de Observações Usadas    4.700000e+01
# Valor Crítico (1%)             -3.577848e+00
# Valor Crítico (5%)             -2.925338e+00
# Valor Crítico (10%)            -2.600774e+00
# dtype: float64
#
# Conclusão:
#
# O valor-p é menor que 0.05 e, portanto, temos evidências para rejeitar a hipótese nula.
# Essa série provavelmente é estacionária.

# %% [markdown]
# ### Dividindo os Dados em Treino e Teste

# %% [markdown]
# Para a preparação dos dados, vamos alternar entre objetos NumPy e Pandas, usando o que cada um oferece de melhor. Fique atento a cada passo.

# %%
# Série Original
X = media_vendas_tecnologia

# %%
# Os primeiros 36 registros da série serão usados como dados de treino
X[:-12]
# Out:
# order_date
# 2014-01-01     449.041429
# 2014-02-01     229.787143
# 2014-03-01    2031.948375
# 2014-04-01     613.028933
# 2014-05-01     564.698588
# 2014-06-01     766.905909
# 2014-07-01     533.608933
# 2014-08-01     708.435385
# 2014-09-01    2035.838133
# 2014-10-01     596.900900
# 2014-11-01    1208.056320
# 2014-12-01    1160.732889
# 2015-01-01     925.070800
# 2015-02-01     431.121250
# 2015-03-01     574.662333
# 2015-04-01     697.559500
# 2015-05-01     831.642857
# 2015-06-01     429.024400
# 2015-07-01     691.397733
# 2015-08-01    1108.902286
# 2015-09-01     950.856400
# 2015-10-01     594.716111
# 2015-11-01    1037.982652
# 2015-12-01    1619.637636
# 2016-01-01     374.671067
# 2016-02-01    1225.891400
# 2016-03-01    1135.150105
# 2016-04-01     875.911882
# 2016-05-01    1601.816167
# 2016-06-01    1023.259500
# 2016-07-01     829.312500
# 2016-08-01     483.620100
# 2016-09-01    1144.170300
# 2016-10-01    1970.835875
# 2016-11-01    1085.642360
# 2016-12-01     970.554870
# Freq: MS, Name: sales, dtype: float64

# %%
# Os últimos 12 registros da série serão usados como dados de teste
X[-12:]
# Out:
# order_date
# 2017-01-01    1195.218071
# 2017-02-01     430.501714
# 2017-03-01    1392.859250
# 2017-04-01     825.559133
# 2017-05-01     678.329400
# 2017-06-01     853.055000
# 2017-07-01    1054.996636
# 2017-08-01     978.842333
# 2017-09-01    1077.704120
# 2017-10-01    1493.439227
# 2017-11-01    1996.750920
# 2017-12-01     955.865652
# Freq: MS, Name: sales, dtype: float64

# %%
# Divisão em treino e teste
treino, teste = np.array(X[:-12]), np.array(X[-12:])

# %%
# Ajusta o shape, pois agora não temos um objeto pd.Series, 
# mas sim um array NumPy, que é necessário para treinar o modelo LSTM
trainset = treino.reshape(-1,1)
testset = teste.reshape(-1,1)

# %%
len(trainset)
# Out:
# 36

# %%
trainset
# Out:
# array([[ 449.04142857],
#        [ 229.78714286],
#        [2031.948375  ],
#        [ 613.02893333],
#        [ 564.69858824],
#        [ 766.90590909],
#        [ 533.60893333],
#        [ 708.43538462],
#        [2035.83813333],
#        [ 596.9009    ],
#        [1208.05632   ],
#        [1160.73288889],
#        [ 925.0708    ],
#        [ 431.12125   ],
#        [ 574.66233333],
#        [ 697.5595    ],
#        [ 831.64285714],
#        [ 429.0244    ],
#        [ 691.39773333],
#        [1108.90228571],
#        [ 950.8564    ],
#        [ 594.71611111],
#        [1037.98265217],
#        [1619.63763636],
#        [ 374.67106667],
#        [1225.8914    ],
#        [1135.15010526],
#        [ 875.91188235],
#        [1601.81616667],
#        [1023.2595    ],
#        [ 829.3125    ],
#        [ 483.6201    ],
#        [1144.1703    ],
#        [1970.835875  ],
#        [1085.64236   ],
#        [ 970.55486957]])

# %%
len(testset)
# Out:
# 12

# %%
testset
# Out:
# array([[1195.21807143],
#        [ 430.50171429],
#        [1392.85925   ],
#        [ 825.55913333],
#        [ 678.3294    ],
#        [ 853.055     ],
#        [1054.99663636],
#        [ 978.84233333],
#        [1077.70412   ],
#        [1493.43922727],
#        [1996.75092   ],
#        [ 955.86565217]])

# %% [markdown]
# ### Função Para o Cálculo da Acurácia

# %%
# Função
def performance(y_true, y_pred): 
    mse = ((y_pred - y_true) ** 2).mean()
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    return( print('MSE das previsões é {}'.format(round(mse, 2))+
                  '\nRMSE das previsões é {}'.format(round(np.sqrt(mse), 2))+
                  '\nMAPE das previsões é {}'.format(round(mape, 2))))

# %% [markdown]
# ## Modelo LSTM

# %% [markdown]
# A rede Long Short-Term Memory, ou LSTM, é uma rede neural recorrente treinada usando Backpropagation Through Time e supera o problema da dissipação do gradiente (isso é explicado no Deep Learning Book).
#
# Como tal, o modelo pode ser usado para criar grandes redes recorrentes que, por sua vez, podem ser usadas para resolver problemas de sequência difíceis no aprendizado de máquina e obter resultados de última geração.
#
# Em vez de neurônios, as redes LSTM possuem blocos de memória conectados através de camadas.
#
# Um bloco possui componentes que o tornam mais inteligente que um neurônio clássico e uma memória para sequências recentes. Um bloco contém portas que gerenciam o estado e a saída do bloco. Um bloco opera sobre uma sequência de entrada e cada porta dentro de um bloco usa as unidades de ativação sigmóide para controlar se são acionadas ou não, condicionando a mudança de estado e a adição de informações que fluem através do bloco.
#
# Existem três tipos de portas dentro de uma unidade:
#
# - Forget Gate: decide condicionalmente quais informações jogar fora do bloco.
# - Input Gate: decide condicionalmente quais valores da entrada atualizar o estado da memória.
# - Output Gate: decide condicionalmente o que enviar com base na entrada e na memória do bloco.
#
# Cada unidade é como uma máquina de mini estado onde os portões das unidades têm pesos que são aprendidos durante o procedimento de treinamento.
#
# Esse modelo é estudado em detalhes no curso <a href="https://www.datascienceacademy.com.br/course?courseid=deep-learning-ii">Deep Learning II</a>.

# %% [markdown]
# ### Preparando os Dados Para Treinamento

# %% [markdown]
# Como regra geral, sempre que você usa uma rede neural, você deve normalizar ou dimensionar seus dados. Usaremos a classe MinMaxScaler da biblioteca sklearn.preprocessing para dimensionar nossos dados entre 0 e 1. O parâmetro feature_range é usado para especificar o intervalo dos dados dimensionados e se não for especificado o intevalo será entre 0 e 1.

# %%
# Cria o scaler
scaler = MinMaxScaler()

# %%
# Treina o scaler nos dados de treino (nunca no dataset completo ou nos dados de teste)
scaler.fit(trainset)
# Out:
# MinMaxScaler()

# %%
# Aplica o mesmo scaler aos dados de treino 
# (Não precisamos aplicar aos dados de teste, pois vamos converter a saída das previsões antes de avaliar o modelo)
trainset = scaler.transform(trainset)

# %%
trainset.shape
# Out:
# (36, 1)

# %%
trainset
# Out:
# array([[0.12139983],
#        [0.        ],
#        [0.99784626],
#        [0.21219877],
#        [0.18543853],
#        [0.29739956],
#        [0.16822437],
#        [0.26502477],
#        [1.        ],
#        [0.20326877],
#        [0.54166199],
#        [0.51545928],
#        [0.38497454],
#        [0.11147753],
#        [0.1909554 ],
#        [0.25900285],
#        [0.33324403],
#        [0.11031652],
#        [0.25559112],
#        [0.48676098],
#        [0.39925188],
#        [0.20205906],
#        [0.44749318],
#        [0.76955219],
#        [0.08022139],
#        [0.55153717],
#        [0.50129424],
#        [0.35775554],
#        [0.75968454],
#        [0.43934106],
#        [0.33195373],
#        [0.14054584],
#        [0.50628867],
#        [0.96400863],
#        [0.47388209],
#        [0.41015881]])

# %% [markdown]
# Aqui definimos os hiperparâmetros.

# %%
# Número de repetições
n_rep = 20

# Número de epochs
num_epochs = 50

# Número de inputs (usaremos 12 séries para prever as 12 séries seguintes)
n_input = 12

# Comprimento das sequências de saída (em número de timesteps)
n_output = 12

# Aqui estamos indicando que nossa série é univariada, logo, apenas 1 recurso
n_features = 1

# Número de amostras de séries temporais em cada lote
size_batch = 10

# %% [markdown]
# O TimeseriesGenerator do Keras transforma automaticamente um conjunto de dados univariado de séries temporais em um dataset para problema de aprendizado supervisionado.
#
# https://keras.io/preprocessing/sequence/

# %%
# Generator
generator = TimeseriesGenerator(trainset, 
                                trainset, 
                                length = n_output,
                                batch_size = size_batch)

# %% [markdown]
# Podemos agora criar o modelo.
#
# Para começar a aplicação de Deep Learning ao nosso problema criaremos um modelo básico de LSTM que chamarei de LSTM Padrão.
#
# Aqui está a principal diferença dos modelos de Deep Learning para outros métodos de previsão de séries temporais. Temos que criar o modelo com cada camada da rede neural.
#
# Como trabalharemos com batches de dados da série que serão passados pela rede várias vezes, vamos criar o modelo e gerar os batches de dados a cada passada de um loop. As camadas de rede nada mais são que operações matemáticas.
#
# Nas próximas aulas ensinarei a você como definir os parâmetros da rede (como número de neurônios e dropout). Por agora, leia os comentários em cada linha de código abaixo.

# %%
# Criação e treinamento do modelo LSTM Padrão

# Criamos uma matriz preenchida com zeros que receberá o resultado das previsões do nosso modelo
resultado = np.zeros((n_input, n_rep))

# Loop
# Vamos repetir o processo de treinamento por 20 vezes e armazenar todos os resultados, pois assim usaremos
# diferentes amostras. Ao final, tiramos a média para encontrar as previsões.
for i in range(n_rep):
    
    # O primeiro passo é criar o modelo, ou seja, um objeto da classe Sequential() do Keras
    modelo_lstm = Sequential()
    
    # Podemos adicionar agora a primeira camada da rede, ou camada de entrada.
    # Esta é a camada que recebe os dados.
    modelo_lstm.add(LSTM(50, activation = 'relu', input_shape = (n_input, n_features)))
    
    # A camada de Dropout aplica regularização à rede, removendo alguns neurônios e evitando overfitting
    modelo_lstm.add(Dropout(0.10))
    
    # Adicionamos a primeira camada intermediária ou oculta
    modelo_lstm.add(Dense(100, activation = 'relu'))
    
    # Adicionamos a segunda camada intermediária ou oculta
    modelo_lstm.add(Dense(100, activation = 'relu'))
    
    # Adicionamos a camada de saída e tudo que precisamos é de 1 neurônio pois estamos prevendo apenas 1 valor.
    modelo_lstm.add(Dense(1))
    
    # Com as camadas prontas, podemos definir a função de perda, nesse caso usaremos o MSE (Mean Squared Error)
    # E indicamos o algoritmo de otimização (minimização da função de perda), em nosso caso ADAM
    modelo_lstm.compile(optimizer = 'adam', loss = 'mean_squared_error')
    
    # Aqui fazemos o treinamento gerando batches de dados
    modelo_lstm.fit_generator(generator, epochs = num_epochs)
    
    # Lista para as previsões
    pred_list = []

    # Gera um batch de dados
    batch = trainset[-n_input:].reshape((1, n_input, n_features))

    # Loop para fazer as previsões
    for j in range(n_input):   
        pred_list.append(modelo_lstm.predict(batch)[0]) 
        batch = np.append(batch[:,1:,:], [[pred_list[j]]], axis = 1)

    # Gera o dataframe com as previsões
    df_predict_modelo_lstm = pd.DataFrame(scaler.inverse_transform(pred_list),
                                      index = X[-n_input:].index, columns = ['Prediction'])

    resultado[:,i] = df_predict_modelo_lstm['Prediction']
    
print(resultado)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 3/3 [==============================] - 3s 75ms/step - loss: 0.1807
# Epoch 2/50
# 3/3 [==============================] - 0s 83ms/step - loss: 0.1460
# Epoch 3/50
# 3/3 [==============================] - 0s 74ms/step - loss: 0.1092
# Epoch 4/50
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0767
# Epoch 5/50
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0540
# Epoch 6/50
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0462
# Epoch 7/50
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0460
# Epoch 8/50
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0604
# Epoch 9/50
# 3/3 [==============================] - 0s 138ms/step - loss: 0.0638
# Epoch 10/50
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0582
# Epoch 11/50
# 3/3 [==============================] - 0s 124ms/step - loss: 0.0519
# Epoch 12/50
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0508
# Epoch 13/50
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0444
# Epoch 14/50
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0469
# Epoch 15/50
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0485
# Epoch 16/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0485
# Epoch 17/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0471
# Epoch 18/50
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0490
# Epoch 19/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0475
# Epoch 20/50
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0484
# Epoch 21/50
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0507
# Epoch 22/50
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0465
# Epoch 23/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0469
# Epoch 24/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0477
# Epoch 25/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0545
# Epoch 26/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0424
# Epoch 27/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0499
# Epoch 28/50
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0451
# Epoch 29/50
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0488
# Epoch 30/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0524
# Epoch 31/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0466
# Epoch 32/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0529
# Epoch 33/50
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0469
# Epoch 34/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0447
# Epoch 35/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0465
# Epoch 36/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0472
# Epoch 37/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0528
# Epoch 38/50
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0506
# Epoch 39/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0472
# Epoch 40/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0491
# Epoch 41/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0457
# Epoch 42/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0464
# Epoch 43/50
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0550
# Epoch 44/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0494
# Epoch 45/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0467
# Epoch 46/50
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0493
# Epoch 47/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0503
# Epoch 48/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0479
# Epoch 49/50
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0483
# Epoch 50/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0494
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 3/3 [==============================] - 1s 58ms/step - loss: 0.1994
# Epoch 2/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.1693
# Epoch 3/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.1405
# Epoch 4/50
# 3/3 [==============================] - 0s 51ms/step - loss: 0.1162
# Epoch 5/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0894
# Epoch 6/50
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0702
# Epoch 7/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0540
# Epoch 8/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0625
# Epoch 9/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0579
# Epoch 10/50
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0608
# Epoch 11/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0575
# Epoch 12/50
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0473
# Epoch 13/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0464
# Epoch 14/50
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0471
# Epoch 15/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0491
# Epoch 16/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0479
# Epoch 17/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0462
# Epoch 18/50
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0463
# Epoch 19/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0486
# Epoch 20/50
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0517
# Epoch 21/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0493
# Epoch 22/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0484
# Epoch 23/50
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0470
# Epoch 24/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0460
# Epoch 25/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0470
# Epoch 26/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0469
# Epoch 27/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0480
# Epoch 28/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0483
# Epoch 29/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0494
# Epoch 30/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0494
# Epoch 31/50
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0502
# Epoch 32/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0507
# Epoch 33/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0453
# Epoch 34/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0462
# Epoch 35/50
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0473
# Epoch 36/50
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0484
# Epoch 37/50
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0497
# Epoch 38/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0493
# Epoch 39/50
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0511
# Epoch 40/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0472
# Epoch 41/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0478
# Epoch 42/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0468
# Epoch 43/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0480
# Epoch 44/50
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0491
# Epoch 45/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0458
# Epoch 46/50
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0481
# Epoch 47/50
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0540
# Epoch 48/50
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0500
# Epoch 49/50
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0480
# Epoch 50/50
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0482
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 3/3 [==============================] - 1s 72ms/step - loss: 0.1908
# Epoch 2/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.1494
# Epoch 3/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.1033
# Epoch 4/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0683
# Epoch 5/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0488
# Epoch 6/50
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0533
# Epoch 7/50
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0651
# Epoch 8/50
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0621
# Epoch 9/50
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0534
# Epoch 10/50
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0526
# Epoch 11/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0442
# Epoch 12/50
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0473
# Epoch 13/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0493
# Epoch 14/50
# 3/3 [==============================] - 0s 101ms/step - loss: 0.0465
# Epoch 15/50
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0486
# Epoch 16/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0500
# Epoch 17/50
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0490
# Epoch 18/50
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0487
# Epoch 19/50
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0506
# Epoch 20/50
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0492
# Epoch 21/50
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0489
# Epoch 22/50
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0521
# Epoch 23/50
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0492
# Epoch 24/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0501
# Epoch 25/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0489
# Epoch 26/50
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0464
# Epoch 27/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0486
# Epoch 28/50
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0517
# Epoch 29/50
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0472
# Epoch 30/50
# 3/3 [==============================] - 0s 102ms/step - loss: 0.0500
# Epoch 31/50
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0496
# Epoch 32/50
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0473
# Epoch 33/50
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0471
# Epoch 34/50
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0471
# Epoch 35/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0473
# Epoch 36/50
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0472
# Epoch 37/50
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0441
# Epoch 38/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0487
# Epoch 39/50
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0489
# Epoch 40/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0532
# Epoch 41/50
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0500
# Epoch 42/50
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0488
# Epoch 43/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0503
# Epoch 44/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0465
# Epoch 45/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0510
# Epoch 46/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0513
# Epoch 47/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0482
# Epoch 48/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0491
# Epoch 49/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0488
# Epoch 50/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0499
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 3/3 [==============================] - 1s 66ms/step - loss: 0.1816
# Epoch 2/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1394
# Epoch 3/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0982
# Epoch 4/50
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0695
# Epoch 5/50
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0503
# Epoch 6/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0439
# Epoch 7/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0617
# Epoch 8/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0661
# Epoch 9/50
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0573
# Epoch 10/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0557
# Epoch 11/50
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0452
# Epoch 12/50
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0501
# Epoch 13/50
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0480
# Epoch 14/50
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0500
# Epoch 15/50
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0521
# Epoch 16/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0497
# Epoch 17/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0495
# Epoch 18/50
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0495
# Epoch 19/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0522
# Epoch 20/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0499
# Epoch 21/50
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0498
# Epoch 22/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0465
# Epoch 23/50
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0454
# Epoch 24/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0490
# Epoch 25/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0467
# Epoch 26/50
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0480
# Epoch 27/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0514
# Epoch 28/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0471
# Epoch 29/50
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0503
# Epoch 30/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0473
# Epoch 31/50
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0469
# Epoch 32/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0466
# Epoch 33/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0482
# Epoch 34/50
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0473
# Epoch 35/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0520
# Epoch 36/50
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0451
# Epoch 37/50
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0529
# Epoch 38/50
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0473
# Epoch 39/50
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0463
# Epoch 40/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0481
# Epoch 41/50
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0466
# Epoch 42/50
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0471
# Epoch 43/50
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0455
# Epoch 44/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0498
# Epoch 45/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0476
# Epoch 46/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0495
# Epoch 47/50
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0482
# Epoch 48/50
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0501
# Epoch 49/50
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0476
# Epoch 50/50
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0494
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 3/3 [==============================] - 1s 56ms/step - loss: 0.1797
# Epoch 2/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.1379
# Epoch 3/50
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0976
# Epoch 4/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0606
# Epoch 5/50
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0557
# Epoch 6/50
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0576
# Epoch 7/50
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0599
# Epoch 8/50
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0610
# Epoch 9/50
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0551
# Epoch 10/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0487
# Epoch 11/50
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0470
# Epoch 12/50
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0480
# Epoch 13/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0480
# Epoch 14/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0463
# Epoch 15/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0483
# Epoch 16/50
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0529
# Epoch 17/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0472
# Epoch 18/50
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0473
# Epoch 19/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0489
# Epoch 20/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0443
# Epoch 21/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0490
# Epoch 22/50
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0508
# Epoch 23/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0450
# Epoch 24/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0512
# Epoch 25/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0489
# Epoch 26/50
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0472
# Epoch 27/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0496
# Epoch 28/50
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0492
# Epoch 29/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0459
# Epoch 30/50
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0505
# Epoch 31/50
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0520
# Epoch 32/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0492
# Epoch 33/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0482
# Epoch 34/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0490
# Epoch 35/50
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0535
# Epoch 36/50
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0495
# Epoch 37/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0499
# Epoch 38/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0496
# Epoch 39/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0450
# Epoch 40/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0471
# Epoch 41/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0477
# Epoch 42/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0476
# Epoch 43/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0493
# Epoch 44/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0491
# Epoch 45/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0486
# Epoch 46/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0513
# Epoch 47/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0466
# Epoch 48/50
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0485
# Epoch 49/50
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0473
# Epoch 50/50
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0487
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 3/3 [==============================] - 1s 56ms/step - loss: 0.1993
# Epoch 2/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.1695
# Epoch 3/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.1350
# Epoch 4/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.1055
# Epoch 5/50
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0736
# Epoch 6/50
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0501
# Epoch 7/50
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0450
# Epoch 8/50
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0536
# Epoch 9/50
# 3/3 [==============================] - 0s 118ms/step - loss: 0.0681
# Epoch 10/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0663
# Epoch 11/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0520
# Epoch 12/50
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0451
# Epoch 13/50
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0462
# Epoch 14/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0458
# Epoch 15/50
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0464
# Epoch 16/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0476
# Epoch 17/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0482
# Epoch 18/50
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0483
# Epoch 19/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0490
# Epoch 20/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0499
# Epoch 21/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0488
# Epoch 22/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0519
# Epoch 23/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0479
# Epoch 24/50
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0479
# Epoch 25/50
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0484
# Epoch 26/50
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0479
# Epoch 27/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0479
# Epoch 28/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0498
# Epoch 29/50
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0482
# Epoch 30/50
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0473
# Epoch 31/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0477
# Epoch 32/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0483
# Epoch 33/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0513
# Epoch 34/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0493
# Epoch 35/50
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0508
# Epoch 36/50
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0486
# Epoch 37/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0482
# Epoch 38/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0496
# Epoch 39/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0474
# Epoch 40/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0471
# Epoch 41/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0455
# Epoch 42/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0476
# Epoch 43/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0515
# Epoch 44/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0500
# Epoch 45/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0503
# Epoch 46/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0524
# Epoch 47/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0491
# Epoch 48/50
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0496
# Epoch 49/50
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0474
# Epoch 50/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0480
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 3/3 [==============================] - 1s 59ms/step - loss: 0.1800
# Epoch 2/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1375
# Epoch 3/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.1000
# Epoch 4/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0749
# Epoch 5/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0514
# Epoch 6/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0617
# Epoch 7/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0604
# Epoch 8/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0610
# Epoch 9/50
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0563
# Epoch 10/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0497
# Epoch 11/50
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0491
# Epoch 12/50
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0507
# Epoch 13/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0489
# Epoch 14/50
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0469
# Epoch 15/50
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0472
# Epoch 16/50
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0503
# Epoch 17/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0489
# Epoch 18/50
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0489
# Epoch 19/50
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0535
# Epoch 20/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0486
# Epoch 21/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0489
# Epoch 22/50
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0500
# Epoch 23/50
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0502
# Epoch 24/50
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0471
# Epoch 25/50
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0497
# Epoch 26/50
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0503
# Epoch 27/50
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0495
# Epoch 28/50
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0447
# Epoch 29/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0510
# Epoch 30/50
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0472
# Epoch 31/50
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0496
# Epoch 32/50
# 3/3 [==============================] - 0s 108ms/step - loss: 0.0497
# Epoch 33/50
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0490
# Epoch 34/50
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0491
# Epoch 35/50
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0526
# Epoch 36/50
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0515
# Epoch 37/50
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0490
# Epoch 38/50
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0507
# Epoch 39/50
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0464
# Epoch 40/50
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0481
# Epoch 41/50
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0476
# Epoch 42/50
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0467
# Epoch 43/50
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0515
# Epoch 44/50
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0539
# Epoch 45/50
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0458
# Epoch 46/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0467
# Epoch 47/50
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0487
# Epoch 48/50
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0509
# Epoch 49/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0487
# Epoch 50/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0492
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 3/3 [==============================] - 1s 58ms/step - loss: 0.2017
# Epoch 2/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.1705
# Epoch 3/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.1477
# Epoch 4/50
# 3/3 [==============================] - 0s 62ms/step - loss: 0.1209
# Epoch 5/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0917
# Epoch 6/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0632
# Epoch 7/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0479
# Epoch 8/50
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0537
# Epoch 9/50
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0606
# Epoch 10/50
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0628
# Epoch 11/50
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0551
# Epoch 12/50
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0523
# Epoch 13/50
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0460
# Epoch 14/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0470
# Epoch 15/50
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0463
# Epoch 16/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0436
# Epoch 17/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0488
# Epoch 18/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0469
# Epoch 19/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0496
# Epoch 20/50
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0509
# Epoch 21/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0486
# Epoch 22/50
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0494
# Epoch 23/50
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0458
# Epoch 24/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0488
# Epoch 25/50
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0464
# Epoch 26/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0466
# Epoch 27/50
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0507
# Epoch 28/50
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0472
# Epoch 29/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0461
# Epoch 30/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0512
# Epoch 31/50
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0523
# Epoch 32/50
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0480
# Epoch 33/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0533
# Epoch 34/50
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0483
# Epoch 35/50
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0472
# Epoch 36/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0472
# Epoch 37/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0483
# Epoch 38/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0509
# Epoch 39/50
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0481
# Epoch 40/50
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0511
# Epoch 41/50
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0467
# Epoch 42/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0464
# Epoch 43/50
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0471
# Epoch 44/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0505
# Epoch 45/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0503
# Epoch 46/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0475
# Epoch 47/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0465
# Epoch 48/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0495
# Epoch 49/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0431
# Epoch 50/50
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0505
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 3/3 [==============================] - 1s 64ms/step - loss: 0.2060
# Epoch 2/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.1634
# Epoch 3/50
# 3/3 [==============================] - 0s 54ms/step - loss: 0.1257
# Epoch 4/50
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0985
# Epoch 5/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0780
# Epoch 6/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0543
# Epoch 7/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0502
# Epoch 8/50
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0525
# Epoch 9/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0613
# Epoch 10/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0648
# Epoch 11/50
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0584
# Epoch 12/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0489
# Epoch 13/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0470
# Epoch 14/50
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0481
# Epoch 15/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0480
# Epoch 16/50
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0476
# Epoch 17/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0459
# Epoch 18/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0498
# Epoch 19/50
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0505
# Epoch 20/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0532
# Epoch 21/50
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0508
# Epoch 22/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0467
# Epoch 23/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0498
# Epoch 24/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0482
# Epoch 25/50
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0487
# Epoch 26/50
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0474
# Epoch 27/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0473
# Epoch 28/50
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0461
# Epoch 29/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0464
# Epoch 30/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0467
# Epoch 31/50
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0431
# Epoch 32/50
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0488
# Epoch 33/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0481
# Epoch 34/50
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0498
# Epoch 35/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0480
# Epoch 36/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0500
# Epoch 37/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0514
# Epoch 38/50
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0506
# Epoch 39/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0481
# Epoch 40/50
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0468
# Epoch 41/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0466
# Epoch 42/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0468
# Epoch 43/50
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0473
# Epoch 44/50
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0488
# Epoch 45/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0494
# Epoch 46/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0497
# Epoch 47/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0499
# Epoch 48/50
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0509
# Epoch 49/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0448
# Epoch 50/50
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0481
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 3/3 [==============================] - 1s 54ms/step - loss: 0.1744
# Epoch 2/50
# 3/3 [==============================] - 0s 65ms/step - loss: 0.1347
# Epoch 3/50
# 3/3 [==============================] - 0s 71ms/step - loss: 0.1002
# Epoch 4/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0683
# Epoch 5/50
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0501
# Epoch 6/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0474
# Epoch 7/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0620
# Epoch 8/50
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0682
# Epoch 9/50
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0578
# Epoch 10/50
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0553
# Epoch 11/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0503
# Epoch 12/50
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0464
# Epoch 13/50
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0495
# Epoch 14/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0513
# Epoch 15/50
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0449
# Epoch 16/50
# 3/3 [==============================] - 0s 161ms/step - loss: 0.0495
# Epoch 17/50
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0509
# Epoch 18/50
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0516
# Epoch 19/50
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0491
# Epoch 20/50
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0484
# Epoch 21/50
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0494
# Epoch 22/50
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0468
# Epoch 23/50
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0516
# Epoch 24/50
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0522
# Epoch 25/50
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0468
# Epoch 26/50
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0459
# Epoch 27/50
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0473
# Epoch 28/50
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0480
# Epoch 29/50
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0464
# Epoch 30/50
# 3/3 [==============================] - 0s 113ms/step - loss: 0.0495
# Epoch 31/50
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0480
# Epoch 32/50
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0494
# Epoch 33/50
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0502
# Epoch 34/50
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0540
# Epoch 35/50
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0473
# Epoch 36/50
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0475
# Epoch 37/50
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0463
# Epoch 38/50
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0515
# Epoch 39/50
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0481
# Epoch 40/50
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0483
# Epoch 41/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0515
# Epoch 42/50
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0512
# Epoch 43/50
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0529
# Epoch 44/50
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0514
# Epoch 45/50
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0468
# Epoch 46/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0499
# Epoch 47/50
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0502
# Epoch 48/50
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0501
# Epoch 49/50
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0456
# Epoch 50/50
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0468
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 3/3 [==============================] - 1s 75ms/step - loss: 0.1853
# Epoch 2/50
# 3/3 [==============================] - 0s 115ms/step - loss: 0.1548
# Epoch 3/50
# 3/3 [==============================] - 0s 125ms/step - loss: 0.1115
# Epoch 4/50
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0750
# Epoch 5/50
# 3/3 [==============================] - 0s 153ms/step - loss: 0.0567
# Epoch 6/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0536
# Epoch 7/50
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0603
# Epoch 8/50
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0629
# Epoch 9/50
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0619
# Epoch 10/50
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0557
# Epoch 11/50
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0500
# Epoch 12/50
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0467
# Epoch 13/50
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0482
# Epoch 14/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0467
# Epoch 15/50
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0477
# Epoch 16/50
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0462
# Epoch 17/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0500
# Epoch 18/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0519
# Epoch 19/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0524
# Epoch 20/50
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0451
# Epoch 21/50
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0527
# Epoch 22/50
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0493
# Epoch 23/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0477
# Epoch 24/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0440
# Epoch 25/50
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0445
# Epoch 26/50
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0490
# Epoch 27/50
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0483
# Epoch 28/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0503
# Epoch 29/50
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0488
# Epoch 30/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0493
# Epoch 31/50
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0456
# Epoch 32/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0478
# Epoch 33/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0495
# Epoch 34/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0473
# Epoch 35/50
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0473
# Epoch 36/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0485
# Epoch 37/50
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0484
# Epoch 38/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0506
# Epoch 39/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0504
# Epoch 40/50
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0485
# Epoch 41/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0470
# Epoch 42/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0494
# Epoch 43/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0457
# Epoch 44/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0501
# Epoch 45/50
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0478
# Epoch 46/50
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0537
# Epoch 47/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0502
# Epoch 48/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0490
# Epoch 49/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0466
# Epoch 50/50
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0463
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 3/3 [==============================] - 1s 58ms/step - loss: 0.1794
# Epoch 2/50
# 3/3 [==============================] - 0s 95ms/step - loss: 0.1356
# Epoch 3/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0968
# Epoch 4/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0603
# Epoch 5/50
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0488
# Epoch 6/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0595
# Epoch 7/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0652
# Epoch 8/50
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0626
# Epoch 9/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0497
# Epoch 10/50
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0461
# Epoch 11/50
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0484
# Epoch 12/50
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0512
# Epoch 13/50
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0477
# Epoch 14/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0486
# Epoch 15/50
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0510
# Epoch 16/50
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0499
# Epoch 17/50
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0470
# Epoch 18/50
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0514
# Epoch 19/50
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0479
# Epoch 20/50
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0478
# Epoch 21/50
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0480
# Epoch 22/50
# 3/3 [==============================] - 0s 116ms/step - loss: 0.0495
# Epoch 23/50
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0487
# Epoch 24/50
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0479
# Epoch 25/50
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0486
# Epoch 26/50
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0454
# Epoch 27/50
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0504
# Epoch 28/50
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0489
# Epoch 29/50
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0490
# Epoch 30/50
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0489
# Epoch 31/50
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0488
# Epoch 32/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0488
# Epoch 33/50
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0463
# Epoch 34/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0477
# Epoch 35/50
# ...
# Epoch 49/50
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0480
# Epoch 50/50
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0469
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 3/3 [==============================] - 1s 59ms/step - loss: 0.1961
# Epoch 2/50
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1560
# Epoch 3/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.1241
# Epoch 4/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0917
# Epoch 5/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0640
# Epoch 6/50
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0525
# Epoch 7/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0579
# Epoch 8/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0615
# Epoch 9/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0584
# Epoch 10/50
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0537
# Epoch 11/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0492
# Epoch 12/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0485
# Epoch 13/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0471
# Epoch 14/50
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0493
# Epoch 15/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0501
# Epoch 16/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0490
# Epoch 17/50
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0493
# Epoch 18/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0486
# Epoch 19/50
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0501
# Epoch 20/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0514
# Epoch 21/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0490
# Epoch 22/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0474
# Epoch 23/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0472
# Epoch 24/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0474
# Epoch 25/50
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0489
# Epoch 26/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0457
# Epoch 27/50
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0499
# Epoch 28/50
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0511
# Epoch 29/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0509
# Epoch 30/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0507
# Epoch 31/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0488
# Epoch 32/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0495
# Epoch 33/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0470
# Epoch 34/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0467
# Epoch 35/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0489
# Epoch 36/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0491
# Epoch 37/50
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0475
# Epoch 38/50
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0479
# Epoch 39/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0474
# Epoch 40/50
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0523
# Epoch 41/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0510
# Epoch 42/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0497
# Epoch 43/50
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0454
# Epoch 44/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0481
# Epoch 45/50
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0487
# Epoch 46/50
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0492
# Epoch 47/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0508
# Epoch 48/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0488
# Epoch 49/50
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0485
# Epoch 50/50
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0487
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 3/3 [==============================] - 2s 65ms/step - loss: 0.1833
# Epoch 2/50
# 3/3 [==============================] - 0s 73ms/step - loss: 0.1404
# Epoch 3/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1026
# Epoch 4/50
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0727
# Epoch 5/50
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0489
# Epoch 6/50
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0609
# Epoch 7/50
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0612
# Epoch 8/50
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0600
# Epoch 9/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0581
# Epoch 10/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0518
# Epoch 11/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0473
# Epoch 12/50
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0468
# Epoch 13/50
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0444
# Epoch 14/50
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0477
# Epoch 15/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0498
# Epoch 16/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0537
# Epoch 17/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0526
# Epoch 18/50
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0529
# Epoch 19/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0497
# Epoch 20/50
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0493
# Epoch 21/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0502
# Epoch 22/50
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0477
# Epoch 23/50
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0475
# Epoch 24/50
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0494
# Epoch 25/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0465
# Epoch 26/50
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0481
# Epoch 27/50
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0454
# Epoch 28/50
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0511
# Epoch 29/50
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0489
# Epoch 30/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0498
# Epoch 31/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0456
# Epoch 32/50
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0467
# Epoch 33/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0477
# Epoch 34/50
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0474
# Epoch 35/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0477
# Epoch 36/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0470
# Epoch 37/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0519
# Epoch 38/50
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0488
# Epoch 39/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0475
# Epoch 40/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0485
# Epoch 41/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0471
# Epoch 42/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0484
# Epoch 43/50
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0463
# Epoch 44/50
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0474
# Epoch 45/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0462
# Epoch 46/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0482
# Epoch 47/50
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0498
# Epoch 48/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0496
# Epoch 49/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0491
# Epoch 50/50
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0524
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 3/3 [==============================] - 1s 58ms/step - loss: 0.1815
# Epoch 2/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1362
# Epoch 3/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.1007
# Epoch 4/50
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0714
# Epoch 5/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0498
# Epoch 6/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0477
# Epoch 7/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0584
# Epoch 8/50
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0702
# Epoch 9/50
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0603
# Epoch 10/50
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0542
# Epoch 11/50
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0548
# Epoch 12/50
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0463
# Epoch 13/50
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0488
# Epoch 14/50
# 3/3 [==============================] - 0s 106ms/step - loss: 0.0490
# Epoch 15/50
# 3/3 [==============================] - 0s 106ms/step - loss: 0.0506
# Epoch 16/50
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0464
# Epoch 17/50
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0504
# Epoch 18/50
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0524
# Epoch 19/50
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0480
# Epoch 20/50
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0510
# Epoch 21/50
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0500
# Epoch 22/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0486
# Epoch 23/50
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0459
# Epoch 24/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0493
# Epoch 25/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0493
# Epoch 26/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0511
# Epoch 27/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0462
# Epoch 28/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0494
# Epoch 29/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0483
# Epoch 30/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0510
# Epoch 31/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0502
# Epoch 32/50
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0482
# Epoch 33/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0476
# Epoch 34/50
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0477
# Epoch 35/50
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0542
# Epoch 36/50
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0517
# Epoch 37/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0505
# Epoch 38/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0452
# Epoch 39/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0499
# Epoch 40/50
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0495
# Epoch 41/50
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0473
# Epoch 42/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0477
# Epoch 43/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0489
# Epoch 44/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0513
# Epoch 45/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0530
# Epoch 46/50
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0486
# Epoch 47/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0500
# Epoch 48/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0488
# Epoch 49/50
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0500
# Epoch 50/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0485
# [[1081.32254722 1075.97987215 1078.09496025 1087.5309896  1114.346793
#   1060.6506506  1071.16403142 1046.0050542  1031.04614531 1056.31869225
#   1022.82052162 1075.98100246 1053.68059135 1055.14176543 1124.82594143
#   1045.48311789 1064.47590498 1082.95978128 1087.89457419 1057.15361811]
#  [1084.25216168 1078.3135416  1081.58661028 1089.0949685  1127.07650583
#   1059.28237763 1073.53618539 1047.68771615 1031.31666731 1058.87815553
#   1015.38337324 1082.56121076 1057.73163956 1056.4206897  1130.27567346
#   1048.44222819 1065.56805819 1086.43549927 1093.45663798 1061.25504607]
#  [1079.94700794 1073.97964556 1076.53038928 1084.77969575 1125.70236599
#   1054.62935606 1068.27300913 1041.9384507  1024.53380972 1054.27362985
#   1006.11721406 1077.66178056 1052.43213175 1051.57637581 1126.69553592
#   1042.43681188 1058.90931993 1082.74599031 1090.1789942  1055.9259886 ]
#  [1076.84531651 1070.58751705 1072.62579757 1081.51378572 1125.90689914
#   1051.0515868  1064.00757788 1037.38984869 1019.0423637  1050.61437027
#    998.46993478 1074.79562519 1048.2088451  1047.78799122 1124.5992864
#   1037.53221453 1053.55044368 1080.00788347 1087.72906381 1051.36134687]
#  [1076.30416484 1069.30999221 1071.15369711 1080.24896347 1130.13750593
#   1048.98154982 1062.03560917 1035.17658468 1015.95106039 1049.11740289
#    992.76755048 1075.60713739 1046.74707895 1046.06339997 1125.38921497
#   1035.37438976 1050.36037239 1079.35972867 1087.50849095 1049.27058746]
#  [1069.72293388 1063.48085119 1063.71552607 1074.71348899 1123.11685164
#   1044.8345325  1054.19520753 1028.0597998  1007.9533297  1041.97844232
#    985.66497528 1067.94392605 1038.31223938 1039.72626318 1119.22571606
#   1026.30926514 1042.51318886 1073.14186701 1081.46884225 1041.09410556]
#  [1068.69214062 1062.00196884 1062.02597458 1073.37557304 1125.3853396
#   1043.34558497 1051.96321259 1025.65788087 1004.96483122 1040.11702916
#    981.64051638 1067.67781766 1036.2090465  1037.86307381 1119.3098976
#   1023.58848979 1039.33921111 1071.96375605 1080.60549705 1038.72060597]
#  [1069.40149389 1061.93614146 1062.08324386 1073.30840005 1130.50819536
#   1042.75922072 1051.41683995 1024.70201133 1003.6460768  1039.90668295
#    978.91382033 1069.63880617 1036.10279691 1037.47403023 1121.05860223
#   1022.77751584 1037.47117753 1072.13265737 1081.41383359 1037.77700841]
#  [1072.94965967 1064.19978522 1064.72828812 1075.45567521 1140.70869428
#   1043.53144102 1053.61347218 1026.90187304 1004.89044574 1042.32517984
#    977.6688055  1075.92954623 1039.35525081 1039.30756229 1126.42415272
#   1025.15263016 1039.32365582 1075.18063194 1084.90715219 1040.13226149]
#  [1070.55780592 1061.7987813  1061.7469483  1073.40802923 1140.13481731
#   1041.74839635 1050.01266603 1023.74705681 1001.36316387 1039.16562705
#    974.83774372 1073.57865294 1035.57736201 1036.55567637 1124.84208878
#   1020.79252159 1035.6719855  1072.86090304 1082.53639766 1035.61396268]
#  [1061.56550586 1054.53769291 1052.49968152 1067.20060952 1127.06267293
#   1037.55691998 1040.52340423 1015.42734787  992.64983627 1030.16670657
#    970.35071695 1061.71594538 1024.23357659 1028.83471133 1116.17865651
#   1009.21982051 1027.18213728 1064.89331408 1074.10145044 1025.02468929]
#  [1060.79360851 1053.71972177 1051.40898157 1066.59847468 1128.16085448
#   1037.04332647 1039.17133245 1014.08313446  991.03730766 1029.03020196
#    968.89250322 1060.94867693 1022.67228891 1027.73830598 1116.46026636
#   1007.35011837 1025.71009065 1064.2658279  1073.56207499 1023.66766565]]

# %% [markdown]
# O mais delicado na criação do modelo é definir o input_shape da primeira camada. É isso que o modelo espera como entrada para cada amostra em termos do número de etapas de tempo e do número de recursos.
#
# Estamos trabalhando com uma série univariada, portanto, o número de recursos é um, para uma variável.
#
# O número de etapas de tempo como entrada é o número que escolhemos para prever as sequências de saída. Em nosso exemplo, estamos usando 12 sequências para prever 12 sequências.
#
# Quase sempre temos várias amostras; portanto, o modelo espera que o componente de entrada dos dados de treinamento tenha as dimensões ou a forma:
#
# [samples, timesteps, features]
#
# Em nosso exemplo, nós temos:
#
# - samples = n_rep (20)
# - timesteps = n_input (12)
# - features = n_features (1)

# %% [markdown]
# Agora calculamos o erro modelo.

# %%
# Vamos criar uma matriz com as mesmas dimensões da matriz de resultado usada no treinamento
resultado_final = np.zeros((resultado.shape[0],1))

# %%
# Loop para gerar as previsões finais
for i in range(resultado.shape[0]):
    resultado_final[i] = np.mean(resultado[i,:])

# %%
# Previsões finais
resultado_final
# Out:
# array([[1068.64382774],
#        [1071.42774732],
#        [1066.46337515],
#        [1062.68138492],
#        [1061.34322408],
#        [1054.35856762],
#        [1052.72237237],
#        [1052.72142775],
#        [1055.63430817],
#        [1052.82752932],
#        [1044.0462698 ],
#        [1043.11573815]])

# %%
# Ajustamos o shape
resultado_final = resultado_final.reshape((12,))

# %%
# Previsões finais
resultado_final
# Out:
# array([1068.64382774, 1071.42774732, 1066.46337515, 1062.68138492,
#        1061.34322408, 1054.35856762, 1052.72237237, 1052.72142775,
#        1055.63430817, 1052.82752932, 1044.0462698 , 1043.11573815])

# %%
# Calculamos e imprimos a performance do modelo
modelo_lstm_performance = performance(testset, resultado_final)
modelo_lstm_performance
# Out:
# MSE das previsões é 154513.46
# RMSE das previsões é 393.08
# MAPE das previsões é 32.21

# %% [markdown]
# Nossa rede não apresentou um resultado magnífico, mas não foi ruim. Está no mesmo nível de um modelo SARIMAX e apenas um pouco abaixo de um modelo Prophet.
#
# A diferença é que ainda temos muitas opções de otimização do Modelo LSTM, conforme veremos nas próximas aulas.
#
# Abaixo o plot das previsões.

# %%
# Plot
plt.figure(figsize = (20, 6))

# Série original
plt.plot(media_vendas_tecnologia.index, 
         media_vendas_tecnologia.values,
         label = 'Valores Observados',
         color = 'Blue')

# Previsões
plt.plot(media_vendas_tecnologia[36:].index, 
         resultado_final,
         label = 'Previsões Com Modelo LSTM Padrão', 
         color = 'Red')

plt.title('Previsões Com Modelo LSTM Padrão')
plt.xlabel('Data')
plt.ylabel('Vendas')
plt.legend()
plt.show()

# %% [markdown]
# Vamos fazer o Forecasting para 12 meses de horizonte de previsão. A função DateOffset() vai nos ajudar a criar as datas.

# %% [markdown]
# Vejamos qual é a última data da nossa série original:

# %%
# Última data da série
media_vendas_tecnologia.index[-1]
# Out:
# Timestamp('2017-12-01 00:00:00', freq='MS')

# %%
# Cria sequência de datas a partir da última data da nossa série original
datas_para_prever_forecasting = [media_vendas_tecnologia.index[-1] + DateOffset(months = x) for x in range(0, 13)]

# %%
# Visualiza as datas criadas
datas_para_prever_forecasting
# Out:
# [Timestamp('2017-12-01 00:00:00'),
#  Timestamp('2018-01-01 00:00:00'),
#  Timestamp('2018-02-01 00:00:00'),
#  Timestamp('2018-03-01 00:00:00'),
#  Timestamp('2018-04-01 00:00:00'),
#  Timestamp('2018-05-01 00:00:00'),
#  Timestamp('2018-06-01 00:00:00'),
#  Timestamp('2018-07-01 00:00:00'),
#  Timestamp('2018-08-01 00:00:00'),
#  Timestamp('2018-09-01 00:00:00'),
#  Timestamp('2018-10-01 00:00:00'),
#  Timestamp('2018-11-01 00:00:00'),
#  Timestamp('2018-12-01 00:00:00')]

# %%
# Nossa série original é um objeto do tipo pd.Series
type(media_vendas_tecnologia)
# Out:
# pandas.core.series.Series

# %%
# Objetos do tipo pd.Series dão mais trabalho para manipular. Vamos converter a série original em dataframe.
df_original = pd.DataFrame(media_vendas_tecnologia)

# %%
# Visualiza os dados
df_original.head()
# Out:
#                   sales
# order_date
# 2014-01-01   449.041429
# 2014-02-01   229.787143
# 2014-03-01  2031.948375
# 2014-04-01   613.028933
# 2014-05-01   564.698588

# %%
# Vamos agora criar um novo dataframe 
# O índice (data) será a sequência de datas futuras
# O nome da coluna de dados extraímos da série original
# ATENÇÃO: Não estamos extraindo os dados da série original, somente o nome da coluna
data_futuras = pd.DataFrame(index = datas_para_prever_forecasting[1:], columns = df_original.columns)

# %%
# Visualiza os dados
# Entendeu por que os valores NaN? São datas futuras, e precisamos agora incluir nossas previsões.
data_futuras
# Out:
#            sales
# 2018-01-01   NaN
# 2018-02-01   NaN
# 2018-03-01   NaN
# 2018-04-01   NaN
# 2018-05-01   NaN
# 2018-06-01   NaN
# 2018-07-01   NaN
# 2018-08-01   NaN
# 2018-09-01   NaN
# 2018-10-01   NaN
# 2018-11-01   NaN
# 2018-12-01   NaN

# %%
# Usamos as datas futuras para extrair as previsões do nosso modelo
df_predict = pd.DataFrame(scaler.inverse_transform(pred_list),
                          index = data_futuras[-n_input:].index, columns = ['Prediction'])

# %%
# Concatenamos a série original com os valores de forecasting de 12 meses além da série
df_forecasting = pd.concat([df_original, df_predict], axis = 1)

# %%
# Visualiza o dataframe
df_forecasting
# Out:
#                   sales   Prediction
# 2014-01-01   449.041429          NaN
# 2014-02-01   229.787143          NaN
# 2014-03-01  2031.948375          NaN
# 2014-04-01   613.028933          NaN
# 2014-05-01   564.698588          NaN
# 2014-06-01   766.905909          NaN
# 2014-07-01   533.608933          NaN
# 2014-08-01   708.435385          NaN
# 2014-09-01  2035.838133          NaN
# 2014-10-01   596.900900          NaN
# 2014-11-01  1208.056320          NaN
# 2014-12-01  1160.732889          NaN
# 2015-01-01   925.070800          NaN
# 2015-02-01   431.121250          NaN
# 2015-03-01   574.662333          NaN
# 2015-04-01   697.559500          NaN
# 2015-05-01   831.642857          NaN
# 2015-06-01   429.024400          NaN
# 2015-07-01   691.397733          NaN
# 2015-08-01  1108.902286          NaN
# 2015-09-01   950.856400          NaN
# 2015-10-01   594.716111          NaN
# 2015-11-01  1037.982652          NaN
# 2015-12-01  1619.637636          NaN
# 2016-01-01   374.671067          NaN
# 2016-02-01  1225.891400          NaN
# 2016-03-01  1135.150105          NaN
# 2016-04-01   875.911882          NaN
# 2016-05-01  1601.816167          NaN
# 2016-06-01  1023.259500          NaN
# 2016-07-01   829.312500          NaN
# 2016-08-01   483.620100          NaN
# 2016-09-01  1144.170300          NaN
# 2016-10-01  1970.835875          NaN
# 2016-11-01  1085.642360          NaN
# 2016-12-01   970.554870          NaN
# 2017-01-01  1195.218071          NaN
# 2017-02-01   430.501714          NaN
# 2017-03-01  1392.859250          NaN
# 2017-04-01   825.559133          NaN
# 2017-05-01   678.329400          NaN
# 2017-06-01   853.055000          NaN
# 2017-07-01  1054.996636          NaN
# 2017-08-01   978.842333          NaN
# 2017-09-01  1077.704120          NaN
# 2017-10-01  1493.439227          NaN
# 2017-11-01  1996.750920          NaN
# 2017-12-01   955.865652          NaN
# 2018-01-01          NaN  1057.153618
# 2018-02-01          NaN  1061.255046
# 2018-03-01          NaN  1055.925989
# 2018-04-01          NaN  1051.361347
# 2018-05-01          NaN  1049.270587
# 2018-06-01          NaN  1041.094106
# 2018-07-01          NaN  1038.720606
# 2018-08-01          NaN  1037.777008
# 2018-09-01          NaN  1040.132261
# 2018-10-01          NaN  1035.613963
# 2018-11-01          NaN  1025.024689
# 2018-12-01          NaN  1023.667666

# %% [markdown]
# ### Previsão x Forecasting

# %% [markdown]
# Esse dataframe acima é para não restar qualquer dúvida do que estamos fazendo.
#
# Nas **previsões** do modelo, usamos os dados de teste, 12 meses que correspondem aos 12 últimos registros da série original (2017-01-01 a 2017-12-01. Fazemos isso para poder calcular a precisão do modelo, comparando as previsões com os valores reais. Esse é o padrão em Machine Learning.
#
# No **forecasting**, criamos 12 meses após a última data da série original. Obviamente, não temos dados históricos para esses meses e o que queremos é exatamente a previsão de vendas. O forecasting significa usar o modelo treinado e prever valores sobre novas datas.
#
# Bingo!

# %% [markdown]
# Vamos colocar o forecasting em um Plot.

# %%
# Plot
plt.figure(figsize = (20, 6))

# Série original
plt.plot(df_forecasting.index, 
         df_forecasting['sales'],
         label = 'Valores Observados',
         color = 'Blue')

# Previsões
plt.plot(df_forecasting.index, 
         df_forecasting['Prediction'],
         label = 'Forecasting Com Modelo LSTM Padrão', 
         color = 'Red')

plt.title('Forecasting Com Modelo LSTM Padrão Em Horizonte de 12 Meses de Previsão')
plt.xlabel('Data')
plt.ylabel('Vendas')
plt.legend()
plt.show()

# %% [markdown]
# E aí está nosso primeiro modelo de Deep Learning para previsão de séries temporais!

# %% [markdown]
# Como estamos até agora:
#
# - Aula 15 --> Modelo ARMA(1,1) - AIC = 550.3, RMSE = 420.2 e MAPE = 29.58
# - Aula 16 --> Modelo ARIMA(6,0,2) - AIC = 559.4, RMSE = 401.5 e MAPE = 26.58
# - Aula 17 --> Modelo SARIMA(0, 0, 0)x(0, 1, 1, 12) - AIC = 176.74, RMSE = 425.89 e MAPE = 34.95
# - Aula 18 --> Modelo SARIMA(1, 1, 0)x(1, 1, 0, 12) - AIC = 146.77, RMSE = 353.57 e MAPE = 30.55
# - Aula 19 --> Modelo SARIMA(1, 1, 0)x(1, 1, 0, 12) com exog  - AIC = 149.66, RMSE = 341.23 e MAPE = 32.54
# - Aula 20 --> Modelo Prophet 1 - RMSE = 347.58 e MAPE = 28.53
# - Aula 21 --> Modelo Prophet 2 - RMSE = 325.52 e MAPE = 26.45
# - Aula 22 --> Modelo LSTM Padrão - RMSE = 395.45 e MAPE = 31.46
#
# Nosso modelo de Deep Learning veio para a briga como um candidato de peso. Nas próximas aulas vamos otimizar o modelo e trabalhar com diferentes arquiteturas LSTM.
