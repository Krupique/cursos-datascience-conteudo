# %% [markdown]
# # Redes Neurais

# %% [markdown]
# ## Neurolab

# %% [markdown]
# https://pythonhosted.org/neurolab/

# %% [markdown]
# https://code.google.com/archive/p/neurolab/

# %% [markdown]
# https://pypi.python.org/pypi/neurolab

# %%
# !pip install neurolab
# Out:
# Collecting neurolab
#   Downloading neurolab-0.3.5.tar.gz (645 kB)
# Building wheels for collected packages: neurolab
#   Building wheel for neurolab (setup.py): started
#   Building wheel for neurolab (setup.py): finished with status 'done'
#   Created wheel for neurolab: filename=neurolab-0.3.5-py3-none-any.whl size=22180 sha256=2e4572bac695a80dc247821667600a09de6ee27e3146ce9ef7cd9d685c8f60dc
#   Stored in directory: c:\users\krupc\appdata\local\pip\cache\wheels\ca\11\83\54cf6b9b67600d6501e849f165ed365d7bd6612cd08c8fc589
# Successfully built neurolab
# Installing collected packages: neurolab
# Successfully installed neurolab-0.3.5

# %%
import neurolab as nl
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %%
# Criando datasets de treino
x = np.linspace(-10,10, 60)
y = np.cos(x) * 0.9
size = len(x)
x_train = x.reshape(size,1)
y_train = y.reshape(size,1)

# %%
# ?nl.net.newff
# Out:
# Signature: nl.net.newff(minmax, size, transf=None)
# Docstring:
# Create multilayer perceptron
#
# :Parameters:
#     minmax: list of list, the outer list is the number of input neurons,
#                     inner lists must contain 2 elements: min and max
#         Range of input value
#     size: the length of list equal to the number of layers except input layer,
#                     the element of the list is the neuron number for corresponding layer
#         Contains the number of neurons for each layer
#     transf: list (default TanSig)
#         List of activation function for each layer
# :Returns:
#     net: Net
# :Example:
#     >>> # create neural net with 2 inputs
#             >>> # input range for each input is [-0.5, 0.5]
#             >>> # 3 neurons for hidden layer, 1 neuron for output
#             >>> # 2 layers including hidden layer and output layer
#     >>> net = newff([[-0.5, 0.5], [-0.5, 0.5]], [3, 1])
#     >>> net.ci
#     2
#     >>> net.co
#     1
#     >>> len(net.layers)
#     2
# File:      c:\users\krupc\anaconda3\lib\site-packages\neurolab\net.py
# Type:      function

# %%
# ?nl.train.train_gd
# Out:
# Signature:       nl.train.train_gd(net, input, target=None, **kwargs)
# Type:            Trainer
# String form:     Trainer(TrainGD)
# File:            c:\users\krupc\anaconda3\lib\site-packages\neurolab\core.py
# Docstring:
# Gradient descent backpropogation
#
# :Support networks:
#     newff (multi-layers perceptron)
# :Parameters:
#     input: array like (l x net.ci)
#         train input patterns
#     target: array like (l x net.co)
#         train target patterns
#     epochs: int (default 500)
#         Number of train epochs
#     show: int (default 100)
#         Print period
#     goal: float (default 0.01)
#         The goal of train
#     lr: float (defaults 0.01)
#         learning rate
#     adapt bool (default False)
#         type of learning
#     rr float (defaults 0.0)
#         Regularization ratio
#         Must be between {0, 1}
# Class docstring: Control of network training
# Init docstring:
# :Parameters:
#     Train: Train instance
#         Train algorithm
#     epochs: int (default 500)
#         Number of train epochs
#     goal: float (default 0.01)
#         The goal of train
#     show: int (default 100)
#         Print period
#     **kwargs: dict
#         other Train parametrs
# Call docstring:
# Run train process
#
# :Parameters:
#     net: Net instance
#         network
#     input: array like (l x net.ci)
#         train input patterns
#     target: array like (l x net.co)
#         train target patterns - only for train with teacher
#     **kwargs: dict
#         other Train parametrs

# %%
# Criando 4 redes com 0, 1, 2, e 3 camadas e randomizando a inicialização
d = [[1,1],[45,1],[45,45,1],[45,45,45,1]]

for i in range(4):
    net = nl.net.newff([[-10, 10]],d[i])
    train_net = nl.train.train_gd(net, x_train, y_train, epochs = 1000, show = 100)
    outp = net.sim(x_train)
    
    # Plot 
    plt.subplot(2, 1, 1)
    plt.plot(train_net)
    plt.xlabel('Epochs')
    plt.ylabel('Squared error')
    x2 = np.linspace(-10.0,10.0,150)
    y2 = net.sim(x2.reshape(x2.size,1)).reshape(x2.size)
    y3 = outp.reshape(size)
    plt.subplot(2, 1, 2)

    plt.suptitle([i ,'Camadas Ocultas'])
    plt.plot(x2, y2, '-',x , y, '.', x, y3, 'p')
    plt.legend(['Y previsto', 'Y observado'])
    plt.show()
# Out:
# Epoch: 100; Error: 12.647981800494856;
# Epoch: 200; Error: 12.647981800494856;
# Epoch: 300; Error: 12.647981800494856;
# Epoch: 400; Error: 12.647981800494856;
# Epoch: 500; Error: 12.647981800494856;
# Epoch: 600; Error: 12.647981800494856;
# Epoch: 700; Error: 12.647981800494856;
# Epoch: 800; Error: 12.647981800494856;
# Epoch: 900; Error: 12.647981800494856;
# Epoch: 1000; Error: 12.647981800494856;
# The maximum number of train epochs is reached
# Epoch: 100; Error: 1.6864739484439917;
# Epoch: 200; Error: 2.1189297421088806;
# Epoch: 300; Error: 1.0376736815145222;
# Epoch: 400; Error: 7.2279867522830585;
# Epoch: 500; Error: 1.954968343522035;
# Epoch: 600; Error: 3.9715618240676833;
# Epoch: 700; Error: 2.742814653648347;
# Epoch: 800; Error: 1.5157003081447638;
# Epoch: 900; Error: 1.4662735544677705;
# Epoch: 1000; Error: 5.482215612200558;
# The maximum number of train epochs is reached
# Epoch: 100; Error: 0.544081544697676;
# Epoch: 200; Error: 0.5537979872185159;
# Epoch: 300; Error: 0.6811663731012595;
# Epoch: 400; Error: 2.1542832882378233;
# Epoch: 500; Error: 1.249457139323451;
# Epoch: 600; Error: 0.762398418316279;
# Epoch: 700; Error: 0.30624872664269404;
# Epoch: 800; Error: 0.2549321157397051;
# Epoch: 900; Error: 0.17884560559316304;
# Epoch: 1000; Error: 0.17745019774956755;
# The maximum number of train epochs is reached
# Epoch: 100; Error: 0.5153565184947093;
# Epoch: 200; Error: 0.6614092606440386;
# Epoch: 300; Error: 0.2349532726690854;
# Epoch: 400; Error: 0.17901166221012182;
# Epoch: 500; Error: 0.1196528039935087;
# Epoch: 600; Error: 0.08577511322388624;
# Epoch: 700; Error: 0.11560976956621125;
# Epoch: 800; Error: 0.15136260146667763;
# Epoch: 900; Error: 0.05412910048262221;
# Epoch: 1000; Error: 0.13095533600783724;
# The maximum number of train epochs is reached
